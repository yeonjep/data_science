# %%
# This cell mounts github to google drive
import os
from google.colab import drive

drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/

if os.path.isdir("/content/gdrive/MyDrive/ITEC419-fa22") == True:
    print("Already git cloned 'ITEC419-fa22.git'")
    # %cd ITEC419-fa22/
    ! git pull https://github.com/soonkijung/ITEC419-fa22.git
else:
    # You need to git clone ITEC419-fa22.git
    ! git clone https://github.com/soonkijung/ITEC419-fa22.git
    # %cd ITEC419-fa22/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive
# Already git cloned 'ITEC419-fa22.git'
# /content/gdrive/MyDrive/ITEC419-fa22
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 2), reused 9 (delta 2), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/soonkijung/ITEC419-fa22
#  * branch            HEAD       -> FETCH_HEAD
# Updating 148ed20..1d03111
# Fast-forward
#  lec/district_demographics2016.csv | 436 ++++++++++++++++++++++++++++++++++++++
#  lec/dugong.csv                    |  28 +++
#  lec/heights.csv                   |   1 +
#  lec/lec17_0.ipynb                 |   1 +
#  lec/shotput.csv                   |  29 +++
#  lec/us_women.csv                  |   1 +
#  6 files changed, 496 insertions(+)
#  create mode 100644 lec/district_demographics2016.csv
#  create mode 100644 lec/dugong.csv
#  create mode 100644 lec/heights.csv
#  create mode 100644 lec/lec17_0.ipynb
#  create mode 100644 lec/shotput.csv
#  create mode 100644 lec/us_women.csv
