# %% [markdown]
# # Lecture 03의 데모
#
# ### Lecture 03의 데모에 대한 코드
#
# 참고자료: https://github.com/data-8/materials-sp22/blob/main/lec/lec04.ipynb

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/ITEC419-fa22/lec
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/ITEC419-fa22/lec

# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Numbers ##

# %% [markdown]
# int/int -> 결과값은 float으로 바뀐다 소숫점 15자리까지 표기, 그 뒤는 삭제

# %%
10/3
# Out:
# 3.3333333333333335

# %%
30
# Out:
# 30

# %%
10/2
# Out:
# 5.0

# %%
10**3
# Out:
# 1000

# %%
10**0.5
# Out:
# 3.1622776601683795

# %% [markdown]
# 아주 큰 수도 파이썬은 자유자재로 다룰 수 있음
# (int는 아주 큰 값도 모두 저장하지만, 실수는 소숫점 15번째자리까지만 다룸)

# %%
1234567**80
# Out:
# ...

# %% [markdown]
# 15번째 자리까지만 표현하므로 결과값이 0으로 나옴

# %%
74353362.123123123123123123123123-74353362.1231231231
# Out:
# 0.0

# %% [markdown]
# int로 형변환 (그냥 계산하면 10/5=2.0)

# %%
int(10/5)
# Out:
# 2

# %%
float(3)
# Out:
# 3.0

# %%
6/4
# Out:
# 1.5

# %%
6/40000
# Out:
# 0.00015

# %% [markdown]
# 뒤에 0을 아무리 많이 붙이더라도
# 6/4*10^x 의 형태로 연산이 수행됨

# %%
6/40000000000000000000
# Out:
# 1.5e-19

# %%
x=5

# %%
2*x
# Out:
# 10

# %%
1234123123123123123123.123124142123
# Out:
# 1.234123123123123e+21

# %% [markdown]
# 실수는 소순점 15번째자리까지만 정확하다

# %% [markdown]
# ## Strings ##

# %%
'Flavor'

# %%
Flavor=1221453251

# %%
'Vanila Flavor'
# Out:
# 'Vanila Flavor'

# %%
123
# Out:
# 123

# %%
'123'
# Out:
# '123'

# %%
print(1234)
# Out:
# 1234

# %%
"Don't put an apostrophe within a single-quoted string"
# Out:
# "Don't put an apostrophe within a single-quoted string"

# %% [markdown]
# 'Don't put an apostrophe within a single-quoted string' 라고 작성하면 'Don'까지만 한 스트링으로 인식되므로 문제 생김

# %%
'you can have "quatation" marks'
# Out:
# 'you can have "quatation" marks'

# %% [markdown]
# 스트링을 여닫는 따옴표와 스트링 내부의 따옴표가 다른 형태이면 써도 됨

# %%
hi = "hello"
hi
# Out:
# 'hello'

# %%
'hello '+'student'
# Out:
# 'hello student'

# %%
x='straw'
y='berry'
x+y
# Out:
# 'strawberry'

# %% [markdown]
# *문자열과 스트링은 연산이 불가능하다* //
# 숫자를 문자열로 변형하면 문자열끼리 붙이는 연산으로 인식되어 가능 //
# int('23.0')은 불가능 //
# float('23.0')으로 해야함

# %%
3*'ha '
# Out:
# 'ha ha ha '

# %%
'ha'+str(10)
# Out:
# 'ha10'

# %%
int('23')+1
# Out:
# 24

# %%
str(int('23')+1)
# Out:
# '24'

# %%
int(23.0)
# Out:
# 23

# %% [markdown]
# ## Types ##

# %%
type(10)
# Out:
# int

# %%
x=10

# %%
type(x)
# Out:
# int

# %%
x=1.0

# %% [markdown]
# x=1.0을 넣는 순간 원래 x=10은 없어지고 x=1.0이 됨

# %%
type(4.5)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %%
type(Table.read_table('nba_salaries.csv'))
# Out:
# datascience.tables.Table

# %% [markdown]
# 패키지.클래스.타입

# %%
t=Table.read_table('nba_salaries.csv')

# %%
t
# Out:
# rank | name             | position | team                   | salary   | season
# 1    | Shaquille O'Neal | C        | Los Angeles Lakers     | 17142000 | 2000
# 2    | Kevin Garnett    | PF       | Minnesota Timberwolves | 16806000 | 2000
# 3    | Alonzo Mourning  | C        | Miami Heat             | 15004000 | 2000
# 4    | Juwan Howard     | PF       | Washington Wizards     | 15000000 | 2000
# 5    | Scottie Pippen   | SF       | Portland Trail Blazers | 14795000 | 2000
# 6    | Karl Malone      | PF       | Utah Jazz              | 14000000 | 2000
# 7    | Larry Johnson    | F        | New York Knicks        | 11910000 | 2000
# 8    | Gary Payton      | PG       | Seattle SuperSonics    | 11020000 | 2000
# 9    | Rasheed Wallace  | PF       | Portland Trail Blazers | 10800000 | 2000
# 10   | Shawn Kemp       | C        | Cleveland Cavaliers    | 10780000 | 2000
# ... (9446 rows omitted)

# %%
type(True)
# Out:
# bool

# %%
abs(-5)
# Out:
# 5

# %%
type(abs)
# Out:
# builtin_function_or_method

# %%
type(abs(-5))
# Out:
# int

# %% [markdown]
# type 함수를 실행하기에 앞서 인자들끼리 계산 우선 하고 type 함수 실행
# 1. abs(-5)
# 2. type(5)

# %%
x=abs
type(x)
# Out:
# builtin_function_or_method

# %%
x(-100)
# Out:
# 100

# %%
type(x(1500))
# Out:
# int

# %% [markdown]
# ## Arrays ##

# %%
first_four = make_array(1, 2, 3, 4)

# %% [markdown]
# 외워두기
# **굵은 텍스트**순차적으로 값이 있는걸로 make_array 함수를 쓰면 배열을 만들 수 있다

# %%
first_four
# Out:
# array([1, 2, 3, 4])

# %%
type(first_four)
# Out:
# numpy.ndarray

# %% [markdown]
# numpy 패키지(파이썬 패키지). array 타입이다

# %%
np.average(first_four)

# %% [markdown]
# 배열 내부의 값을 모두 더해서 평균 구함

# %%
np.sum(first_four)
# Out:
# 10

# %%
first_four + 3
# Out:
# array([4, 5, 6, 7])

# %% [markdown]
# dimention이 다를 때는 이걸 확장한 후에 더함 //
# (3이 [3,3,3,3]이라는 배열로 바뀐 후 더해짐) //
# 덧셈 연산이면 3을 각 원소에 모두 더하는 의미

# %%
first_four*3
# Out:
# array([ 3,  6,  9, 12])

# %%
first_four**2
# Out:
# array([ 1,  4,  9, 16])

# %%
first_four
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# 하지만 실제로 기존의 배열이 바뀌지는 않았다.

# %%
second_four=make_array(5,6,7,8)

# %%
first_four + second_four
# Out:
# array([ 6,  8, 10, 12])

# %%
only_three = make_array(5,6,7)

# %% [markdown]
# first_four + only_three //
# 배열의 원소 개수가 다른데 덧셈 연산을 하려면 오류 남 //
# 동일하게 만들 수 있는 방법은 배열의 사이즈가 1일 때 뿐

# %%
only_one=make_array(5)

# %%
first_four+only_one
# Out:
# array([6, 7, 8, 9])

# %%
s=make_array('ha','he','ho')
s
# Out:
# array(['ha', 'he', 'ho'],
#       dtype='<U2')

# %%
s.item(0)
# Out:
# 'ha'

# %%
0번째 아이템
3번째 아이템은 없으니까 s.item(3) 하면 오류남 (index outofbound)

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
nba = Table.read_table('nba_salaries.csv').where('season', 2020).drop('season')
nba.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>rank</th> <th>name</th> <th>position</th> <th>team</th> <th>salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>Stephen Curry    </td> <td>PG      </td> <td>Golden State Warriors</td> <td>40231758</td>
#         </tr>
#         <tr>
#             <td>2   </td> <td>Chris Paul       </td> <td>PG      </td> <td>Oklahoma City Thunder</td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>3   </td> <td>Russell Westbrook</td> <td>PG      </td> <td>Houston Rockets      </td> <td>38506482</td>
#         </tr>
#         <tr>
#             <td>4   </td> <td>John Wall        </td> <td>PG      </td> <td>Washington Wizards   </td> <td>38199000</td>
#         </tr>
#         <tr>
#             <td>5   </td> <td>Kevin Durant     </td> <td>SF      </td> <td>Brooklyn Nets        </td> <td>38199000</td>
#         </tr>
#     </tbody>
# </table>
# ...

# %%
warriors = nba.where('team', 'Golden State Warriors')
warriors.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>rank</th> <th>name</th> <th>position</th> <th>team</th> <th>salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>Stephen Curry      </td> <td>PG      </td> <td>Golden State Warriors</td> <td>40231758</td>
#         </tr>
#         <tr>
#             <td>13  </td> <td>Klay Thompson      </td> <td>SG      </td> <td>Golden State Warriors</td> <td>32742000</td>
#         </tr>
#         <tr>
#             <td>60  </td> <td>Draymond Green     </td> <td>PF      </td> <td>Golden State Warriors</td> <td>18539130</td>
#         </tr>
#         <tr>
#             <td>223 </td> <td>Kevon Looney       </td> <td>PF      </td> <td>Golden State Warriors</td> <td>4464226 </td>
#         </tr>
#         <tr>
#             <td>316 </td> <td>Willie Cauley-Stein</td> <td>C       </td> <td>Golden State Warriors</td> <td>2177483 </td>
#         </tr>
#     </tbody>
# ...
